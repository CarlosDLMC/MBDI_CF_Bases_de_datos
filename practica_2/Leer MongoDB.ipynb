# %%
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017/')
db = client['love4pets']

# %%
db.list_collection_names()
# Out:
# ['detalle_orden',
#  'suministro',
#  'producto',
#  'departamento',
#  'empleado',
#  'mascota',
#  'cliente',
#  'proveedor',
#  'orden']

# %%
import pandas as pd

# %%
orden = db["orden"]
orden
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'love4pets'), 'orden')

# %%
for o in orden.find():
    print(o)
# Out:
# {'_id': ObjectId('616557634fb5f1c3243ef9ea'), 'orden_id': 1, 'cliente_id': 2, 'fecha': '2017-01-01 00:00:000'}
# {'_id': ObjectId('616557634fb5f1c3243ef9eb'), 'orden_id': 2, 'cliente_id': 1, 'fecha': '2018-02-01 00:00:000'}
# {'_id': ObjectId('616557634fb5f1c3243ef9ec'), 'orden_id': 3, 'cliente_id': 2, 'fecha': '2016-03-01 00:00:000'}
# {'_id': ObjectId('616557634fb5f1c3243ef9ed'), 'orden_id': 4, 'cliente_id': 3, 'fecha': '2016-04-01 00:00:000'}
# {'_id': ObjectId('616557634fb5f1c3243ef9ee'), 'orden_id': 5, 'cliente_id': 4, 'fecha': '2017-05-01 00:00:000'}
# {'_id': ObjectId('616557634fb5f1c3243ef9ef'), 'orden_id': 6, 'cliente_id': 5, 'fecha': '2016-06-01 00:00:000'}
# {'_id': ObjectId('616557634fb5f1c3243ef9f0'), 'orden_id': 7, 'cliente_id': 11, 'fecha': '2017-07-01 00:00:000'}
# {'_id': ObjectId('616557634fb5f1c3243ef9f1'), 'orden_id': 8, 'cliente_id': 2, 'fecha': '2017-01-01 00:00:000'}
# ...

# %%
orden_df = pd.DataFrame(list(orden.find()))

# %%
orden_df
# Out:
#                          _id  orden_id  cliente_id                 fecha
# 0   616557634fb5f1c3243ef9ea         1           2  2017-01-01 00:00:000
# 1   616557634fb5f1c3243ef9eb         2           1  2018-02-01 00:00:000
# 2   616557634fb5f1c3243ef9ec         3           2  2016-03-01 00:00:000
# 3   616557634fb5f1c3243ef9ed         4           3  2016-04-01 00:00:000
# 4   616557634fb5f1c3243ef9ee         5           4  2017-05-01 00:00:000
# 5   616557634fb5f1c3243ef9ef         6           5  2016-06-01 00:00:000
# 6   616557634fb5f1c3243ef9f0         7          11  2017-07-01 00:00:000
# 7   616557634fb5f1c3243ef9f1         8           2  2017-01-01 00:00:000
# 8   616557634fb5f1c3243ef9f2         9           6  2018-08-01 00:00:000
# 9   616557634fb5f1c3243ef9f3        10           2  2017-01-01 00:00:000
# 10  616557634fb5f1c3243ef9f4        11           6  2017-09-01 00:00:000
# 11  616557634fb5f1c3243ef9f5        12          12  2018-01-01 00:00:000
# ...

# %%
departamento = db['departamento']
departamento
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'love4pets'), 'departamento')

# %%
departamento_df = pd.DataFrame(list(departamento.find()))
departamento_df
# Out:
#                         _id  departamento_id            nombre
# 0  616557634fb5f1c3243ef9c2                1          finanzas
# 1  616557634fb5f1c3243ef9c3                2            ventas
# 2  616557634fb5f1c3243ef9c4                3  recursos humanos
# 3  616557634fb5f1c3243ef9c5                4         marketing
# 4  616557634fb5f1c3243ef9c6                5       veterinario
# 5  616557634fb5f1c3243ef9c7                6       informatica
# 6  616557634fb5f1c3243ef9c8                7     investigacion

# %%
departamento_df.drop(columns=["_id"])
# Out:
#    departamento_id            nombre
# 0                1          finanzas
# 1                2            ventas
# 2                3  recursos humanos
# 3                4         marketing
# 4                5       veterinario
# 5                6       informatica
# 6                7     investigacion

# %%
cliente = db["cliente"]
cliente_df = pd.DataFrame(list(cliente.find())).drop(columns=["_id"])
cliente_df
# Out:
#     cliente_id                   nombre                   email   telefono  \
# 0            1    Mario Flores Gallardo   marioflores@gmail.com  036-15-36
# 1            2      Arnau Medina Garcia   arnaumedina@gmail.com  094-10-88
# 2            3        Ivan Medina Rubio    ivanmedina@gmail.com  083-08-72
# 3            4       Jan Vargas Santana     vargasjan@gmail.com  780-65-24
# 4            5    Carlos Costa Guerrero  carloscostag@gmail.com  180-65-24
# 5            6    Roberto Martin Ortega  robertmartin@gmail.com  742-63-27
# 6            7  Gabriel Gonzalez Ortega     gabogonzo@gmail.com  780-13-14
# 7            8        Rayan Leon Ferrer        rayito@gmail.com  430-65-24
# 8            9       Aitor Ruiz Sanchez  aitorsanchez@gmail.com  780-77-24
# 9           10      Eric Rubio Carrasco     ericrubio@gmail.com  780-65-79
# 10          11        Alberto Sanz Ruiz        albert@gmail.com  781-15-24
# ...
